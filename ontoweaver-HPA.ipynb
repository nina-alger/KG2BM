# %% [markdown]
# # HPA
# - I've mapped the HPA.
# - The schema and config file have been adapted to only include HPA db
# ----------
# - I've added `project.toml` `uv.lock and` `.venv/` for **uv** use
# -  They have been copied paste from the `ontoweaver-vignette` and modified to fit my project exactly
# -----

# %%
# Activate uv and run if modified venv
! uv sync

# %% [markdown]
# ## Running ontoweaver
# ---
# - Current cd : /KG2BM
# ### Files needed :
# - data : `rna_tissue_consensus.tsv`
# - mapping : `HPA.yaml`
# - `schema_config.yaml`
# - `biocypher_config.yaml`
# ----
# ### Syntax :
# `! uv run ontoweaver PathToData:PathToMappingFile --biocypher-config PathToConfigFile --biocypher-scheam PathToSchemaFile -a suffix`.
# - The `-a suffix` option is used to add a suffix to the generated nodes. Each suffix represents the ontological type of the node.

# %%
! uv run ontoweave ./data/rna_tissue_consensus.tsv:./KG2BM/adapters/HPA.yaml --biocypher-config ./config/biocypher_config.yaml --biocypher-schema ./config/schema_config.yaml -a suffix
# Out:
# ...
# INFO -- This is BioCypher v0.12.5.
# INFO -- Logging into `biocypher-log/biocypher-20260219-151149.log`.
# WARNING:ontoweaver:Skip output validation for columns: `Tissue`. This could result in some empty or `nan` nodes. To enable output validation set `validate_output` to `True`.
# Traceback (most recent call last):
#   File "/home/nina/M2Internship/KG2BM/.venv/bin/ontoweave", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/home/nina/M2Internship/ontoweaver-vignette/.venv/lib/python3.12/site-packages/ontoweaver/ontoweave.py", line 344, in main
#     import_file = ontoweaver.weave(
#                   ^^^^^^^^^^^^^^^^^
#   File "/home/nina/M2Internship/ontoweaver-vignette/.venv/lib/python3.12/site-packages/ontoweaver/__init__.py", line 81, in weave
#     fnodes, fedges = reconciliate(bc_nodes, bc_edges, reconciliate_sep, raise_errors)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ### Log output
# `.sh` file that is needed for futur visualization in Neo4j
